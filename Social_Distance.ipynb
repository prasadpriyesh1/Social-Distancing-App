# %%
import cv2
import math

# %%
#some observations made by manually running some experiment on my laptop webcam
#all the dimensions are in inch
#actual width of the object
WIDTH = 57
# Perpendicular distance from the camera
DISTANCE = 38
#pixels covered by the object in the image
PIXELS = 480
# focus of the camera
# this value will be used in future calculations
FOCUS = PIXELS * DISTANCE / WIDTH
FOCUS
# Out:
# 320.0

# %%
#taking a general face dimensions
Face = (9,8)
faces = []
cap = cv2.VideoCapture(0)

# %%
face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
while True:
    status , image = cap.read()
    faces =[]
    face_cor = face_model.detectMultiScale(image)
    for x in range(0,len(face_cor)):
            x1=face_cor[x][0]
            y1=face_cor[x][1]
            x2=x1+face_cor[x][2]
            y2=y1+face_cor[x][3]
            image=cv2.rectangle(image,(x1,y1),(x2,y2),[0,255,0])
    for face in face_cor:
        y = round((Face[0]*FOCUS/(face[2])),5)
        if face[0]   < 240:
            P = 480 - 2*(face[0] )
            P_ = y * P /38
            x = round((P_ * y / (FOCUS * 2)),5)
            x = -x
        elif face[0]   > 240:
            P = 2*(face[0] ) - 480
            P_ = y * P /38
            x = round((P_ *y / (FOCUS * 2)),5)
        else:
            x = 0
        faces.append((x,y))
    print(faces)
    warning = []
    for face in faces:
        warning.append([])
    if len(faces)>1:
        for a in range(len(faces)):
            for b in range(a + 1,len(faces)):
                dist = (faces[a][0] - faces[b][0])**2 + ( faces[a][1] - faces[b][1])**2
                dist = round(math.sqrt(dist),5)
                if dist < 40:
                    warning[a].append(b)
                    warning[b].append(a)
                    
    print(warning)
    for war in range(len(warning)):
        if len(warning[war])>0:
            x1=face_cor[war][0]
            y1=face_cor[war][1]
            x2=x1+face_cor[war][2]
            y2=y1+face_cor[war][3]
            image=cv2.rectangle(image,(x1,y1),(x2,y2),[0,0,255])
    str1 = ''
    n = 0
    if len(warning)>0:
        for war in range(len(warning)):
            
            str1 =str1 + '\n'
            str1 += 'Person '
            war3 = str(n)
            str1 += war3
            str1 += ': '
            for war2 in warning[war]:
                str1 += str(war2)
                str1 += ' , '
            n = n+1
    y0, dy = 50, 20
    for i, line in enumerate(str1.split('\n')):
        y1 = y0 + i*dy
        y1 = int(y1)
        cv2.putText(image, line , (0,y1) ,cv2.FONT_HERSHEY_SIMPLEX,0.5,[0,0,255],3)
    
    cv2.imshow('hello' , image)
    if cv2.waitKey(10) == 13:
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# [(54.79515, 75.78947)]
# [[]]
# [(54.79515, 75.78947)]
# [[]]
# [(27.43962, 54.33962)]
# [[]]
# [(30.77546, 55.38462)]
# [[]]
# [(30.17543, 53.33333)]
# [[]]
# [(25.143, 49.65517)]
# [[]]
# [(-8.68563, 33.88235), (22.50704, 49.65517), (-2.83423, 75.78947)]
# [[1], [0, 2], [1]]
# [(22.32345, 52.36364)]
# [[]]
# [(14.39639, 49.65517)]
# [[]]
# [(9.4522, 45.71429)]
# [[]]
# [(9.4522, 45.71429)]
# [[]]
# [(9.39539, 43.63636), (33.88122, 36.4557)]
# [[1], [0]]
# [(10.82707, 45.71429)]
# [[]]
# [(10.49137, 45.0)]
# [[]]
# [(11.17079, 45.71429)]
# [[]]
# [(10.32484, 45.0), (0.95477, 15.2381)]
# [[1], [0]]
# [(11.17914, 46.45161)]
# [[]]
# [(10.65521, 45.71429)]
# [[]]
# [(11.35659, 46.45161)]
# [[]]
# [(11.17914, 46.45161)]
# [[]]
# [(9.99178, 45.0)]
# [[]]
# [(10.31149, 45.71429)]
# [[]]
# [(10.31149, 45.71429)]
# [[]]
# [(10.82425, 46.45161)]
# [[]]
# [(10.48335, 45.71429)]
# [[]]
# [(10.32484, 45.0)]
# [[]]
# [(9.84815, 44.30769), (0.56688, 13.64929)]
# [[1], [0]]
# [(10.15831, 45.0)]
# [[]]
# [(9.84815, 44.30769)]
# [[]]
# [(10.15831, 45.0)]
# [[]]
# [(11.0017, 46.45161)]
# [[]]
# [(10.48335, 45.71429)]
# [[]]
# [(9.52526, 44.30769), (2.69066, 16.94118)]
# [[1], [0]]
# [(11.55789, 48.0)]
# [[]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(7.59752, 42.98507)]
# [[]]
# [(8.93663, 45.71429)]
# [[]]
# [(8.55659, 44.30769), (2.05925, 15.82418)]
# [[1], [0]]
# [(9.04092, 44.30769)]
# [[]]
# [(9.08221, 43.63636)]
# [[]]
# [(9.20237, 44.30769)]
# [[]]
# [(9.36381, 44.30769)]
# [[]]
# [(9.04092, 44.30769)]
# [[]]
# [(9.20237, 44.30769)]
# [[]]
# [(8.76903, 43.63636)]
# [[]]
# [(8.92562, 43.63636)]
# [[]]
# [(8.92562, 43.63636)]
# [[]]
# [(9.20237, 44.30769)]
# [[]]
# [(8.92562, 43.63636)]
# [[]]
# [(9.04092, 44.30769)]
# [[]]
# [(7.73654, 41.73913)]
# [[]]
# [(8.76903, 43.63636)]
# [[]]
# [(8.45585, 43.63636)]
# [[]]
# [(7.29362, 42.98507)]
# [[]]
# [(6.26359, 43.63636)]
# [[]]
# [(5.0048, 44.30769)]
# [[]]
# [(7.63021, 46.45161)]
# [[]]
# [(9.79592, 45.71429)]
# [[]]
# [(16.0956, 51.42857)]
# [[]]
# [(18.03915, 52.36364)]
# [[]]
# [(17.58817, 52.36364)]
# [[]]
# [(17.30994, 53.33333)]
# [[]]
# [(15.90643, 53.33333)]
# [[]]
# [(11.49996, 52.36364)]
# [[]]
# []
# []
# [(-2.01806, 55.38462), (-2.43121, 42.98507)]
# [[1], [0]]
# [(-5.58506, 54.33962)]
# [[]]
# [(-8.07225, 55.38462)]
# [[]]
# [(-10.75214, 56.47059), (5.24495, 18.82353)]
# [[], []]
# [(6.26423, 20.57143)]
# [[]]
# [(5.22309, 19.32886), (-14.06619, 50.52632)]
# [[1], [0]]
# [(-16.53061, 51.42857), (6.10756, 20.71942)]
# [[1], [0]]
# [(-19.51579, 48.0), (4.50582, 18.11321)]
# [[1], [0]]
# [(-19.07627, 45.71429), (4.73684, 18.46154)]
# [[1], [0]]
# [(-150.34568, 110.76923), (-20.96671, 45.71429), (4.73204, 18.34395)]
# [[], [2], [1]]
# [(4.91173, 18.58065)]
# [[]]
# [(4.50296, 18.0)]
# [[]]
# [(4.39638, 18.0)]
# [[]]
# [(-34.49273, 42.98507), (4.50582, 18.11321)]
# [[], []]
# [(-37.61669, 44.30769), (4.98943, 18.94737)]
# [[], []]
# [(-36.17224, 43.63636), (4.6562, 18.58065)]
# [[], []]
# [(-33.58103, 42.98507), (4.34445, 18.22785)]
# [[], []]
# [(-33.25767, 44.30769), (4.20987, 18.0)]
# [[], []]
# [(-28.08079, 41.73913), (4.15318, 18.22785)]
# [[1], [0]]
# [(-28.39786, 41.14286), (4.18051, 18.22785)]
# [[1], [0]]
# [(-31.12548, 42.35294), (3.94722, 17.8882)]
# [[], []]
# [(-36.63651, 45.0), (4.15318, 18.22785)]
# [[], []]
# [(-36.97091, 44.30769), (3.97353, 17.8882)]
# [[], []]
# [(-39.46752, 45.0), (4.31641, 18.46154)]
# [[], []]
# [(4.15091, 18.34395)]
# [[]]
# [(4.09853, 18.22785)]
# [[]]
# [(3.86827, 17.8882)]
# [[]]
# [(4.07121, 18.22785)]
# [[]]
# [(3.9662, 18.11321)]
# [[]]
# [(3.89459, 17.8882)]
# [[]]
# [(3.86349, 18.0)]
# [[]]
# [(3.81564, 17.8882)]
# [[]]
# [(3.8102, 18.0)]
# [[]]
# [(3.98007, 18.46154)]
# [[]]
# [(3.88279, 18.7013)]
# [[]]
# [(3.63411, 18.58065)]
# [[]]
# [(3.75888, 18.82353)]
# [[]]
# [(3.87543, 18.82353), (-47.02823, 48.81356)]
# [[], []]
# [(4.73662, 19.86207), (-45.47368, 48.0)]
# [[], []]
# [(3.90727, 18.22785), (-1.93414, 62.6087), (-46.83228, 48.81356)]
# [[], [], []]
# [(3.94342, 18.0), (-45.47368, 48.0)]
# [[], []]
# [(4.04714, 18.11321), (-45.47368, 48.0)]
# [[], []]
# [(3.66868, 17.24551), (-45.47368, 48.0)]
# [[], []]
# [(-1.93414, 62.6087), (-48.66387, 49.65517)]
# [[], []]
# [(4.18205, 18.11321), (-1.85271, 61.2766), (-45.28421, 48.0)]
# [[], [], []]
# [(3.97661, 17.77778), (-48.25833, 49.65517)]
# [[], []]
# [(4.45656, 18.46154), (-44.90526, 48.0)]
# [[], []]
# [(-46.63633, 48.81356), (3.92796, 17.66871)]
# [[], []]
# [(4.18205, 18.11321), (-41.07412, 45.71429)]
# [[], []]
# [(3.46953, 16.94118), (-39.80058, 45.0)]
# [[], []]
# [(3.85485, 17.56098), (-42.40977, 46.45161)]
# [[], []]
# [(3.87265, 17.77778), (-43.81164, 47.21311)]
# [[], []]
# [(-43.81164, 47.21311)]
# [[]]
# [(-42.23232, 46.45161)]
# [[]]
# [(3.7331, 17.45455), (-42.40977, 46.45161)]
# [[], []]
# [(3.48154, 16.74419), (-43.99496, 47.21311)]
# [[], []]
# [(3.3432, 16.74419), (-42.40977, 46.45161)]
# [[], []]
# [(4.02859, 17.77778), (-1.93414, 62.6087), (-46.63633, 48.81356)]
# [[], [], []]
# [(3.89864, 17.77778), (-45.28421, 48.0)]
# [[], []]
# [(-46.83228, 48.81356)]
# [[]]
# [(-45.28421, 48.0)]
# [[]]
# [(-45.47368, 48.0), (3.49314, 16.94118)]
# [[], []]
# [(-48.4611, 49.65517)]
# [[]]
# [(-45.47368, 48.0)]
# [[]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(3.72181, 17.14286)]
# [[]]
# []
# []
# [(3.52193, 17.24551)]
# [[]]
# [(3.42233, 16.94118)]
# [[]]
# [(3.52238, 16.84211)]
# [[]]
# [(3.90557, 17.56098)]
# [[]]
# [(3.55536, 16.6474), (-45.28421, 48.0)]
# [[], []]
# [(3.47456, 16.45714), (-47.02823, 48.81356)]
# [[], []]
# [(3.81848, 17.14286)]
# [[]]
# [(-48.66387, 49.65517), (4.0831, 17.56098), (-1.93414, 62.6087)]
# [[], [], []]
# [(3.44702, 16.55172)]
# [[]]
# [(-48.66387, 49.65517), (4.05881, 17.45455)]
# [[], []]
# []
# []
# []
# []
# []
# []
# [(4.65237, 17.77778)]
# [[]]
# []
# []
# [(-45.47368, 48.0)]
# [[]]
# [(-45.47368, 48.0)]
# [[]]
# [(-45.28421, 48.0)]
# [[]]
# [(-43.44502, 47.21311)]
# [[]]
# [(-40.55855, 45.71429)]
# [[]]
# [(-37.80222, 45.0)]
# [[]]
# [(-34.44976, 43.63636)]
# [[]]
# [(-29.79785, 42.35294)]
# [[]]
# [(-28.26276, 42.98507)]
# [[]]
# [(-28.57577, 44.30769)]
# [[]]
# [(-27.84104, 45.71429)]
# [[]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(-3.78553, 30.96774)]
# [[]]
# [(-3.78553, 30.96774)]
# [[]]
# []
# []
# []
# []
# [(4.60182, 37.4026)]
# [[]]
# [(4.60182, 37.4026)]
# [[]]
